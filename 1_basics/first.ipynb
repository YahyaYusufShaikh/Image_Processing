# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    - -------------------------------------- 1.8/39.0 MB 9.0 MB/s eta 0:00:05
#    --- ------------------------------------ 3.1/39.0 MB 7.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/39.0 MB 7.1 MB/s eta 0:00:05
#    ------ --------------------------------- 6.0/39.0 MB 6.9 MB/s eta 0:00:05
#    ------- -------------------------------- 7.3/39.0 MB 6.8 MB/s eta 0:00:05
#    -------- ------------------------------- 8.7/39.0 MB 6.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/39.0 MB 6.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.3/39.0 MB 6.6 MB/s eta 0:00:05
#    ------------ --------------------------- 12.6/39.0 MB 6.6 MB/s eta 0:00:05
#    -------------- ------------------------- 13.9/39.0 MB 6.6 MB/s eta 0:00:04
# ...

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('./images/flemingo.jpg')

# %%
img
